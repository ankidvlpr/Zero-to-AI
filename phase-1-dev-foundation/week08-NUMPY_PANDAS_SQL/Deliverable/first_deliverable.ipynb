# %%
import pandas as pd

df = pd.read_csv("titanic.csv", index_col="PassengerId")
print(df)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
print(df.head())
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
print(df.tail())
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 887                 0       2                     Montvila, Rev. Juozas
# 888                 1       1              Graham, Miss. Margaret Edith
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# PassengerId
# 887            male  27.0      0      0      211536  13.00   NaN        S
# 888          female  19.0      0      0      112053  30.00   B42        S
# 889          female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 890            male  26.0      0      0      111369  30.00  C148        C
# 891            male  32.0      0      0      370376   7.75   NaN        Q

# %%
print(df.describe())
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    str
#  3   Sex       891 non-null    str
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    str
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    str
#  10  Embarked  889 non-null    str
# dtypes: float64(2), int64(4), str(5)
# memory usage: 76.7 KB
# None

# %%
series = df["Age"]

# %%
print(series)
# Out:
# PassengerId
# 1      22.0
# 2      38.0
# 3      26.0
# 4      35.0
# 5      35.0
#        ...
# 887    27.0
# 888    19.0
# 889     NaN
# 890    26.0
# 891    32.0
# Name: Age, Length: 891, dtype: float64

# %%
print(df.shape)
# Out:
# (891, 11)

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    str
#  3   Sex       891 non-null    str
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    str
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    str
#  10  Embarked  889 non-null    str
# dtypes: float64(2), int64(4), str(5)
# memory usage: 76.7 KB
# None

# %%
print(df.loc[807][["Name", "Age", "Survived", "Fare", "Sex"]])
# Out:
# Name        Andrews, Mr. Thomas Jr
# Age                           39.0
# Survived                         0
# Fare                           0.0
# Sex                           male
# Name: 807, dtype: object

# %%
df["Cabin"] = df["Cabin"].replace("NaN", "None")

# %%
print(df.iloc[400])
# Out:
# Survived                     1
# Pclass                       3
# Name        Niskanen, Mr. Juha
# Sex                       male
# Age                       39.0
# SibSp                        0
# Parch                        0
# Ticket       STON/O 2. 3101289
# Fare                     7.925
# Cabin                      NaN
# Embarked                     S
# Name: 401, dtype: object

# %%
print(df.loc[5:100, ["Name", "Age"]])
print("\n")
print(df.loc[df[f"Age"] > 30, ["Name", "Age"]])
print("\n")
print(df.loc[:, "Age":"Fare"].to_string())
print("\n")
print(df.loc[4, ["Age", "Fare"]])
# Out:
#                                                           Name   Age
# PassengerId
# 5                                     Allen, Mr. William Henry  35.0
# 6                                             Moran, Mr. James   NaN
# 7                                      McCarthy, Mr. Timothy J  54.0
# 8                               Palsson, Master. Gosta Leonard   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# ...                                                        ...   ...
# 96                                 Shorney, Mr. Charles Joseph   NaN
# 97                                   Goldschmidt, Mr. George B  71.0
# 98                             Greenfield, Mr. William Bertram  23.0
# 99                        Doling, Mrs. John T (Ada Julia Bone)  34.0
# 100                                          Kantor, Mr. Sinai  34.0
#
# [96 rows x 2 columns]
#
#
#                                                           Name   Age
# PassengerId
# ...

# %%
print(df.iloc[0:5, 0:4])
print("\n")
print(df.iloc[[0, 2, 10], [1, 4]])
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
#
#
#              Pclass   Age
# PassengerId
# 1                 3  22.0
# 3                 3  26.0
# 11                3   4.0

# %%
print(df["Cabin"])
print("\n")
print(df["Cabin"].fillna("None").head(5))
# Out:
# PassengerId
# 1       NaN
# 2       C85
# 3       NaN
# 4      C123
# 5       NaN
#        ...
# 887     NaN
# 888     B42
# 889     NaN
# 890    C148
# 891     NaN
# Name: Cabin, Length: 891, dtype: str
#
#
# PassengerId
# 1    None
# 2     C85
# 3    None
# 4    C123
# 5    None
# Name: Cabin, dtype: str
